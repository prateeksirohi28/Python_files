# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hotel_bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
pd.set_option('display.max_columns', None)
print(df.head())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# No of differnt hotels
df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
# Cancellation rate of hotel bookings
df['is_canceled'].value_counts(normalize = True) * 100
# Out:
# is_canceled
# 0    62.958372
# 1    37.041628
# Name: proportion, dtype: float64

# %%
# Conclusion: from here we can conclude that cancellation rate is 39 per cent.

# %%
#  What is the average daily rate (ADR) for each hotel type?
df.groupby('hotel')['adr'].mean()
# Out:
# hotel
# City Hotel      105.304465
# Resort Hotel     94.952930
# Name: adr, dtype: float64

# %%
# Conclusion: it means that no of people on average visiting hotels daily

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# . How many bookings were made each year?
df.arrival_date_year.value_counts().sort_index()
# Out:
# arrival_date_year
# 2015    21996
# 2016    56707
# 2017    40687
# Name: count, dtype: int64

# %%
# conclsion: from here we can also get the maximum no of booking is in 2016

# %%
#  How many people booked with children?
df[df.children > 0].value_counts().sum()
# Out:
# 6

# %%
#  What are the most common customer types?
df.customer_type.max()
# Out:
# 'Transient-Party'

# %%
# How many bookings included special requests?
df[df.total_of_special_requests> 0].shape[0]
# Out:
# 49072

# %%
# deposit type for each hotel
df.groupby('hotel')['deposit_type'].value_counts()
# Out:
# hotel         deposit_type
# City Hotel    No Deposit      66442
#               Non Refund      12868
#               Refundable         20
# Resort Hotel  No Deposit      38199
#               Non Refund       1719
#               Refundable        142
# Name: count, dtype: int64

# %%
# same room not assigned as done at booking time
df[df.reserved_room_type != df.assigned_room_type].shape[0]
# Out:
# 14917

# %%
# hotel who have waiting list 
df.groupby('hotel')['days_in_waiting_list'].value_counts()
# Out:
# hotel         days_in_waiting_list
# City Hotel    0                       75887
#               39                        226
#               58                        164
#               44                        140
#               31                        127
#                                       ...
# Resort Hotel  93                          1
#               105                         1
#               109                         1
#               116                         1
#               142                         1
# Name: count, Length: 159, dtype: int64

# %%
 # how many customers are repeated guest?
df[df.is_repeated_guest == 1].shape[0]
# Out:
# 3810

# %%
# distribution channel hotel wise
df.groupby('hotel')['distribution_channel'].value_counts()
# Out:
# hotel         distribution_channel
# City Hotel    TA/TO                   68945
#               Direct                   6780
#               Corporate                3408
#               GDS                       193
#               Undefined                   4
# Resort Hotel  TA/TO                   28925
#               Direct                   7865
#               Corporate                3269
#               Undefined                   1
# Name: count, dtype: int64

# %%
# . Does lead time affect the likelihood of cancellation?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='is_canceled', y='lead_time', data=df)
plt.title('Lead Time vs Cancellation')
plt.xlabel('Is Canceled')
plt.ylabel('Lead Time')
plt.show()

# %%
# concluson: yes we can say that lead time affect the cancellation
