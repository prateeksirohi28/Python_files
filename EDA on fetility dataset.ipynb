# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fertility.csv')

# %%
df
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# ..     ...  ...               ...                        ...
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# ...

# %%
df.isnull().sum()
# Out:
# Season                                   0
# Age                                      0
# Childish diseases                        0
# Accident or serious trauma               0
# Surgical intervention                    0
# High fevers in the last year             0
# Frequency of alcohol consumption         0
# Smoking habit                            0
# Number of hours spent sitting per day    0
# Diagnosis                                0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    99
# True      1
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#    Season  Age Childish diseases Accident or serious trauma  \
# 20   fall   30                no                         no
#
#    Surgical intervention High fevers in the last year  \
# 20                   yes       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 20                      once a week         never
#
#     Number of hours spent sitting per day Diagnosis
# 20                                      5    Normal

# %%
df.describe(include ='all')
# Out:
#         Season         Age Childish diseases Accident or serious trauma  \
# count      100  100.000000               100                        100
# unique       4         NaN                 2                          2
# top     spring         NaN               yes                         no
# freq        37         NaN                87                         56
# mean       NaN   30.110000               NaN                        NaN
# std        NaN    2.246861               NaN                        NaN
# min        NaN   27.000000               NaN                        NaN
# 25%        NaN   28.000000               NaN                        NaN
# 50%        NaN   30.000000               NaN                        NaN
# 75%        NaN   32.000000               NaN                        NaN
# max        NaN   36.000000               NaN                        NaN
#
#        Surgical intervention High fevers in the last year  \
# ...

# %%
df.columns
# Out:
# Index(['Season', 'Age', 'Childish diseases', 'Accident or serious trauma',
#        'Surgical intervention', 'High fevers in the last year',
#        'Frequency of alcohol consumption', 'Smoking habit',
#        'Number of hours spent sitting per day', 'Diagnosis'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i].unique())
    print(df[i].value_counts(normalize = True)*100)
    print('-----' * 30)
# Out:
# ['spring' 'fall' 'winter' 'summer']
# Season
# spring    37.0
# fall      31.0
# winter    28.0
# summer     4.0
# Name: proportion, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [30 35 27 32 36 29 33 28 31 34]
# Age
# 28    28.0
# 30    27.0
# 32    17.0
# 27     7.0
# 33     7.0
# 29     5.0
# 35     4.0
# 36     2.0
# 31     2.0
# 34     1.0
# Name: proportion, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ['no' 'yes']
# Childish diseases
# yes    87.0
# no     13.0
# Name: proportion, dtype: float64
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ['yes' 'no']
# Accident or serious trauma
# no     56.0
# yes    44.0
# ...

# %%
df.head()
# Out:
#    Season  Age Childish diseases Accident or serious trauma  \
# 0  spring   30                no                        yes
# 1  spring   35               yes                         no
# 2  spring   27               yes                         no
# 3  spring   32                no                        yes
# 4  spring   30               yes                        yes
#
#   Surgical intervention High fevers in the last year  \
# 0                   yes       more than 3 months ago
# 1                   yes       more than 3 months ago
# 2                    no       more than 3 months ago
# 3                   yes       more than 3 months ago
# 4                    no       more than 3 months ago
#
#   Frequency of alcohol consumption Smoking habit  \
# 0                      once a week    occasional
# 1                      once a week         daily
# 2             hardly ever or never         never
# 3             hardly ever or never         never
# ...

# %%
# people who need fertility treatment based on the above information

# %%
# Bar plot for Diagnosis (target)
sns.countplot(data = df, x='Diagnosis')
plt.title('Diagnosis Distribution')
plt.show()

# %%
# Categorical vs Target
sns.countplot(data=df, x='Smoking habit', hue='Diagnosis')
plt.title('Smoking Habit vs Diagnosis')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Surgical intervention').Diagnosis.value_counts()
# Out:
# Surgical intervention  Diagnosis
# no                     Normal       44
#                        Altered       5
# yes                    Normal       44
#                        Altered       7
# Name: count, dtype: int64

# %%
for i in df.columns:
    print(df.groupby(i).Diagnosis.value_counts(normalize = True)*100)
    print('----'* 40)
# Out:
# Season  Diagnosis
# fall    Normal       80.645161
#         Altered      19.354839
# spring  Normal       89.189189
#         Altered      10.810811
# summer  Normal       75.000000
#         Altered      25.000000
# winter  Normal       96.428571
#         Altered       3.571429
# Name: proportion, dtype: float64
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Age  Diagnosis
# 27   Normal        85.714286
#      Altered       14.285714
# 28   Normal       100.000000
# 29   Normal       100.000000
# 30   Normal        74.074074
#      Altered       25.925926
# 31   Normal       100.000000
# 32   Normal        82.352941
#      Altered       17.647059
# 33   Normal       100.000000
# 34   Normal       100.000000
# 35   Normal        75.000000
#      Altered       25.000000
# 36   Normal       100.000000
# Name: proportion, dtype: float64
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
le = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = le.fit_transform(df[i])

# %%
X = df.drop('Diagnosis', axis=1)
y = df['Diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# %%
model = RandomForestClassifier(random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = model.predict(X_test) 

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.95      1.00      0.97        18
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.75      0.82        20
# weighted avg       0.95      0.95      0.94        20
